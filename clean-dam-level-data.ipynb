# %%
import numpy as np
import pandas as pd
import re

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# Lets read the data and see what we're dealing with

# %%
file_location = 'data/Dam-levels-update-2012-2017_20171212.csv'
data = pd.read_csv(file_location, header = [2,3,4], encoding = 'latin-1')
data.head()
# Out:
#   Unnamed: 0_level_0 WEMMERSHOEK Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                 DATE      HEIGHT            STORAGE            Current
#   Unnamed: 0_level_2         (m)               (Ml)                  %
# 0          01-Jan-12       48.23             44 621               76.1
# 1          02-Jan-12       48.21             44 571               76.0
# 2          03-Jan-12       48.17             44 471               75.8
# 3          04-Jan-12       48.13             44 372               75.7
# 4          05-Jan-12       48.11             44 322               75.6
#
#   Unnamed: 4_level_0 STEENBRAS LOWER Unnamed: 6_level_0 Unnamed: 7_level_0  \
#            Last Year          HEIGHT            STORAGE            Current
#                    %             (m)               (Ml)                  %
# 0                NaN           20.34             23 549               70.3
# 1                NaN           20.31             23 460               70.0
# 2                NaN           20.28             23 372               69.7
# 3                NaN           20.26             23 313               69.6
# 4                NaN           20.23             23 224               69.3
#
#   Unnamed: 8_level_0 STEENBRAS UPPER         ...         Unnamed: 51_level_0  \
#            Last Year          HEIGHT         ...                     Current
#                    %             (m)         ...                           %
# 0                NaN           24.17         ...                        89.2
# 1                NaN           24.17         ...                        88.3
# 2                NaN           24.15         ...                        87.9
# 3                NaN           24.17         ...                        87.5
# 4                NaN           24.05         ...                        87.2
#
#   Unnamed: 52_level_0 TOTAL STORED - BIG 6 Unnamed: 54_level_0  \
#             Last Year              STORAGE             Current
#                     %                 (Ml)                   %
# 0                 NaN              695 783               77.46
# 1                 NaN              692 990               77.15
# 2                 NaN              690 324               76.85
# 3                 NaN              687 282               76.52
# 4                 NaN              683 355               76.08
#
#   Unnamed: 55_level_0 Unnamed: 56_level_0 LAND-en ZEEZICHT  \
#             Last Year Unnamed: 56_level_1           HEIGHT
#                     % Unnamed: 56_level_2              (m)
# 0                 NaN                 NaN              NaN
# 1                 NaN                 NaN              NaN
# 2                 NaN                 NaN              NaN
# 3                 NaN                 NaN              NaN
# 4                 NaN                 NaN              NaN
#
#   Unnamed: 58_level_0 Unnamed: 59_level_0 Unnamed: 60_level_0
#               STORAGE             Current           Last Year
#                  (Ml)                   %                   %
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
# [5 rows x 61 columns]

# %% [markdown]
# # Collapsing the column names

# %% [markdown]
# First we're going to deal with the column names and 'flatten' them out into a single level. The columns names have been represented in the DataFrame in a MultiIndex, which allows for multiple levels of column names. Where it says 'Unnamed...', this represents a blank space in the original csv file.
#
# We can also see that totals have been pre-calculated for the Big 6 dams. We don't want this is the final dataset.

# %%
data.columns
# Out:
# MultiIndex(levels=[['ALEXANDRA', 'BERG RIVER', 'DE VILLIERS', 'HELY-HUTCHINSON', 'KLEINPLAATS', 'LAND-en ZEEZICHT', 'LEWIS GAY', 'STEENBRAS LOWER', 'STEENBRAS UPPER', 'THEEWATERSKLOOF', 'TOTAL STORED - BIG 6', 'Unnamed: 0_level_0', 'Unnamed: 10_level_0', 'Unnamed: 11_level_0', 'Unnamed: 12_level_0', 'Unnamed: 14_level_0', 'Unnamed: 15_level_0', 'Unnamed: 16_level_0', 'Unnamed: 18_level_0', 'Unnamed: 19_level_0', 'Unnamed: 20_level_0', 'Unnamed: 22_level_0', 'Unnamed: 23_level_0', 'Unnamed: 24_level_0', 'Unnamed: 26_level_0', 'Unnamed: 27_level_0', 'Unnamed: 28_level_0', 'Unnamed: 2_level_0', 'Unnamed: 30_level_0', 'Unnamed: 31_level_0', 'Unnamed: 32_level_0', 'Unnamed: 34_level_0', 'Unnamed: 35_level_0', 'Unnamed: 36_level_0', 'Unnamed: 38_level_0', 'Unnamed: 39_level_0', 'Unnamed: 3_level_0', 'Unnamed: 40_level_0', 'Unnamed: 42_level_0', 'Unnamed: 43_level_0', 'Unnamed: 44_level_0', 'Unnamed: 46_level_0', 'Unnamed: 47_level_0', 'Unnamed: 48_level_0', 'Unnamed: 4_level_0', 'Unnamed: 50_level_0', 'Unnamed: 51_level_0', 'Unnamed: 52_level_0', 'Unnamed: 54_level_0', 'Unnamed: 55_level_0', 'Unnamed: 56_level_0', 'Unnamed: 58_level_0', 'Unnamed: 59_level_0', 'Unnamed: 60_level_0', 'Unnamed: 6_level_0', 'Unnamed: 7_level_0', 'Unnamed: 8_level_0', 'VICTORIA', 'VOËLVLEI', 'WEMMERSHOEK', 'WOODHEAD'], ['Current', 'DATE', 'HEIGHT', 'Last Year', 'STORAGE', 'Unnamed: 56_level_1'], ['%', '(Ml)', '(m)', 'Unnamed: 0_level_2', 'Unnamed: 56_level_2']],
#            labels=[[11, 59, 27, 36, 44, 7, 54, 55, 56, 8, 12, 13, 14, 58, 15, 16, 17, 3, 18, 19, 20, 60, 21, 22, 23, 57, 24, 25, 26, 0, 28, 29, 30, 2, 31, 32, 33, 4, 34, 35, 37, 6, 38, 39, 40, 9, 41, 42, 43, 1, 45, 46, 47, 10, 48, 49, 50, 5, 51, 52, 53], [1, 2, 4, 0, 3, 2, 4, 0, 3, 2, 4, 0, 3, 2, 4, 0, 3, 2, 4, 0, 3, 2, 4, 0, 3, 2, 4, 0, 3, 2, 4, 0, 3, 2, 4, 0, 3, 2, 4, 0, 3, 2, 4, 0, 3, 2, 4, 0, 3, 2, 4, 0, 3, 4, 0, 3, 5, 2, 4, 0, 3], [3, 2, 1, 0, 0, 2, 1, 0, 0, 2, 1, 0, 0, 2, 1, 0, 0, 2, 1, 0, 0, 2, 1, 0, 0, 2, 1, 0, 0, 2, 1, 0, 0, 2, 1, 0, 0, 2, 1, 0, 0, 2, 1, 0, 0, 2, 1, 0, 0, 2, 1, 0, 0, 1, 0, 0, 4, 2, 1, 0, 0]])

# %%
# Break multi-level column names into individual lists
header_0 = [h[0] for h in data.columns[1:]]
header_1 = [h[1] for h in data.columns[1:]]
header_2 = [h[2] for h in data.columns[1:]]

# Fill 'Unnamed' top-level column names with dam names from left to right
for idx, h in enumerate(header_0):
    if re.search(r'^Unnamed', h) is not None:
        header_0[idx] = header_0[idx - 1]

header_0 = [h.title() for h in header_0]
header_1 = [h.lower() for h in header_1]
header_2 = [h.lower() for h in header_2]

col_names = ['date']
# Join all 3 levels of the column names together
col_names = col_names + list(map('_'.join, zip(header_0, header_1, header_2)))

data.columns = pd.Index(col_names)
# Get rid of 'totals'
data = data.drop([col for col in data.columns if re.match(r'^Total Stored', col)], axis = 1)

data['date'] = pd.to_datetime(data['date'])

# %%
data.head()
# Out:
#         date  Wemmershoek_height_(m) Wemmershoek_storage_(ml)  \
# 0 2012-01-01                   48.23                   44 621
# 1 2012-01-02                   48.21                   44 571
# 2 2012-01-03                   48.17                   44 471
# 3 2012-01-04                   48.13                   44 372
# 4 2012-01-05                   48.11                   44 322
#
#    Wemmershoek_current_%  Wemmershoek_last year_%  Steenbras Lower_height_(m)  \
# 0                   76.1                      NaN                       20.34
# 1                   76.0                      NaN                       20.31
# 2                   75.8                      NaN                       20.28
# 3                   75.7                      NaN                       20.26
# 4                   75.6                      NaN                       20.23
#
#   Steenbras Lower_storage_(ml)  Steenbras Lower_current_%  \
# 0                       23 549                       70.3
# 1                       23 460                       70.0
# 2                       23 372                       69.7
# 3                       23 313                       69.6
# 4                       23 224                       69.3
#
#    Steenbras Lower_last year_%  Steenbras Upper_height_(m)  \
# 0                          NaN                       24.17
# 1                          NaN                       24.17
# 2                          NaN                       24.15
# 3                          NaN                       24.17
# 4                          NaN                       24.05
#
#                ...              Theewaterskloof_current_%  \
# 0              ...                                   74.5
# 1              ...                                   74.3
# 2              ...                                   74.0
# 3              ...                                   73.7
# 4              ...                                   73.1
#
#    Theewaterskloof_last year_%  Berg River_height_(m)  \
# 0                          NaN                  39.33
# 1                          NaN                  39.12
# 2                          NaN                  39.01
# 3                          NaN                  38.91
# 4                          NaN                  38.84
#
#    Berg River_storage_(ml) Berg River_current_%  Berg River_last year_%  \
# 0                  115 930                 89.2                     NaN
# 1                  114 850                 88.3                     NaN
# 2                  114 280                 87.9                     NaN
# 3                  113 770                 87.5                     NaN
# 4                  113 410                 87.2                     NaN
#
#    Land-En Zeezicht_height_(m)  Land-En Zeezicht_storage_(ml)  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#    Land-En Zeezicht_current_%  Land-En Zeezicht_last year_%
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
# [5 rows x 57 columns]

# %% [markdown]
# # Dealing with dates

# %% [markdown]
# It's always a good idea to sense-check data. Date are especially susceptible to being messed up because of the various different ways that they can be formatted.
#
# We can see below that the minimum date is 1 Jan 2012. This is fine. However, the maximum date is 22 May *2021*, which is obviously wrong, since that date hasn't yet occured. We are going to need to investigate what's going on here a little further.

# %%
data.shape
data['date'].min()
data['date'].max()
# Out:
# (2182, 57)
# Timestamp('2012-01-01 00:00:00')
# Timestamp('2021-05-22 00:00:00')
#            date  Wemmershoek_height_(m) Wemmershoek_storage_(ml)  \
# 2162 2017-12-02                   41.68                    30110
# 2163 2017-12-03                   41.70                    30149
# 2164 2017-12-04                   41.73                    30208
# 2165 2017-12-05                   41.74                    30228
# 2166 2017-12-06                   41.75                    30248
# 2167 2017-12-07                     NaN                      NaN
# 2168 2017-12-08                     NaN                      NaN
# 2169 2017-12-09                     NaN                      NaN
# 2170 2017-12-10                     NaN                      NaN
# 2171 2017-12-11                     NaN                      NaN
# 2172 2017-12-12                     NaN                      NaN
# 2173 2017-12-13                     NaN                      NaN
# 2174 2017-12-14                     NaN                      NaN
# 2175 2017-12-15                     NaN                      NaN
# 2176 2017-12-16                     NaN                      NaN
# 2177 2017-12-17                     NaN                      NaN
# 2178 2017-12-18                     NaN                      NaN
# 2179 2017-12-19                     NaN                      NaN
# 2180 2017-12-20                     NaN                      NaN
# 2181 2017-12-21                     NaN                      NaN
#
#       Wemmershoek_current_%  Wemmershoek_last year_%  \
# 2162              51.343701                51.613123
# 2163              51.410204                51.309597
# 2164              51.510811                50.975377
# 2165              51.544915                50.637746
# 2166              51.579019                50.274538
# 2167                    NaN                      NaN
# 2168                    NaN                      NaN
# 2169                    NaN                      NaN
# 2170                    NaN                      NaN
# 2171                    NaN                      NaN
# 2172                    NaN                      NaN
# 2173                    NaN                      NaN
# 2174                    NaN                      NaN
# 2175                    NaN                      NaN
# 2176                    NaN                      NaN
# 2177                    NaN                      NaN
# 2178                    NaN                      NaN
# 2179                    NaN                      NaN
# 2180                    NaN                      NaN
# 2181                    NaN                      NaN
#
#       Steenbras Lower_height_(m) Steenbras Lower_storage_(ml)  \
# 2162                       18.45                        18334
# 2163                       18.39                        18182
# 2164                       18.38                        18157
# 2165                       18.38                        18157
# 2166                       18.34                        18056
# 2167                         NaN                          NaN
# 2168                         NaN                          NaN
# 2169                         NaN                          NaN
# 2170                         NaN                          NaN
# 2171                         NaN                          NaN
# 2172                         NaN                          NaN
# 2173                         NaN                          NaN
# 2174                         NaN                          NaN
# 2175                         NaN                          NaN
# 2176                         NaN                          NaN
# 2177                         NaN                          NaN
# 2178                         NaN                          NaN
# 2179                         NaN                          NaN
# 2180                         NaN                          NaN
# 2181                         NaN                          NaN
#
#       Steenbras Lower_current_%  Steenbras Lower_last year_%  \
# 2162                  54.700600                    48.942328
# 2163                  54.247098                    48.366501
# 2164                  54.172509                    48.151684
# 2165                  54.172509                    47.936868
# 2166                  53.871170                    47.289435
# 2167                        NaN                          NaN
# 2168                        NaN                          NaN
# 2169                        NaN                          NaN
# 2170                        NaN                          NaN
# 2171                        NaN                          NaN
# 2172                        NaN                          NaN
# 2173                        NaN                          NaN
# 2174                        NaN                          NaN
# 2175                        NaN                          NaN
# 2176                        NaN                          NaN
# 2177                        NaN                          NaN
# 2178                        NaN                          NaN
# 2179                        NaN                          NaN
# 2180                        NaN                          NaN
# 2181                        NaN                          NaN
#
#       Steenbras Upper_height_(m)              ...               \
# 2162                       25.01              ...
# 2163                       25.01              ...
# 2164                       25.02              ...
# 2165                       25.03              ...
# 2166                       24.94              ...
# 2167                         NaN              ...
# 2168                         NaN              ...
# 2169                         NaN              ...
# 2170                         NaN              ...
# 2171                         NaN              ...
# 2172                         NaN              ...
# 2173                         NaN              ...
# 2174                         NaN              ...
# 2175                         NaN              ...
# 2176                         NaN              ...
# 2177                         NaN              ...
# 2178                         NaN              ...
# 2179                         NaN              ...
# 2180                         NaN              ...
# 2181                         NaN              ...
#
#      Theewaterskloof_current_%  Theewaterskloof_last year_%  \
# 2162                 22.918940                    46.031971
# 2163                 22.804610                    46.031971
# 2164                 22.539714                    46.031971
# 2169                           NaN
# 2170                           NaN
# 2171                           NaN
# 2172                           NaN
# 2173                           NaN
# 2174                           NaN
# 2175                           NaN
# 2176                           NaN
# 2177                           NaN
# 2178                           NaN
# 2179                           NaN
# 2180                           NaN
# 2181                           NaN
#
# [20 rows x 57 columns]

# %% [markdown]
# Looking at the last 20 rows of the dataset, we can see that the last actual date is '2017-12-06', even though there are a few more rows after that with dates but no data.

# %%
data.tail(20)
# Out:
#            date  Wemmershoek_height_(m) Wemmershoek_storage_(ml)  \
# 2147 2017-11-17                   41.07                    28921
# 2148 2017-11-18                   41.07                    28921
# 2149 2017-11-19                   41.08                    28941
# 2150 2017-11-20                   41.09                    28960
# 2151 2017-11-21                   41.19                    29152
# 2152 2017-11-22                   41.36                    29483
# 2153 2017-11-23                   41.45                    29657
# 2154 2017-11-24                   41.50                    29756
# 2155 2017-11-25                   41.52                    29795
# 2156 2017-11-26                   41.55                    29854
# 2157 2017-11-27                   41.61                    29972
# 2158 2017-11-28                   41.58                    29913
# 2159 2017-11-29                   41.62                    29992
# 2160 2017-11-30                   41.64                    30031
# 2161 2017-12-01                   41.67                    30090
# 2162 2017-12-02                   41.68                    30110
# 2163 2017-12-03                   41.70                    30149
# 2164 2017-12-04                   41.73                    30208
# 2165 2017-12-05                   41.74                    30228
# 2166 2017-12-06                   41.75                    30248
#
#       Wemmershoek_current_%  Wemmershoek_last year_%  \
# 2147              49.316213                56.503649
# 2148              49.316213                56.188186
# 2149              49.350317                55.906828
# 2150              49.382716                55.557261
# 2151              49.710115                55.069572
# 2152              50.274538                54.721711
# 2153              50.571243                54.445468
# 2154              50.740059                54.203329
# 2155              50.806562                53.857172
# 2156              50.907169                53.683241
# 2157              51.108383                53.239888
# 2158              51.007776                52.900552
# 2159              51.142487                52.593616
# 2160              51.208990                52.187777
# 2161              51.309597                51.848441
# 2162              51.343701                51.613123
# 2163              51.410204                51.309597
# 2164              51.510811                50.975377
# 2165              51.544915                50.637746
# 2166              51.579019                50.274538
#
#       Steenbras Lower_height_(m) Steenbras Lower_storage_(ml)  \
# 2147                       18.47                        18385
# 2148                       18.48                        18410
# 2149                       18.46                        18359
# 2150                       18.41                        18233
# 2151                       18.45                        18334
# 2152                       18.53                        18536
# 2153                       18.56                        18612
# 2154                       18.56                        18612
# 2155                       18.54                        18562
# 2156                       18.52                        18511
# 2157                       18.52                        18511
# 2158                       18.52                        18511
# 2159                       18.49                        18435
# 2160                       18.47                        18385
# 2161                       18.45                        18334
# 2162                       18.45                        18334
# 2163                       18.39                        18182
# 2164                       18.38                        18157
# 2165                       18.38                        18157
# 2166                       18.34                        18056
#
#       Steenbras Lower_current_%  Steenbras Lower_last year_%  \
# 2147                  54.852761                    54.247098
# 2148                  54.927350                    53.945759
# 2149                  54.775189                    53.569830
# 2150                  54.399260                    53.271474
# 2151                  54.700600                    52.904496
# 2152                  55.303279                    52.391324
# 2156               68.048612                          8.0
# 2157               67.871702                          8.0
# 2158               67.656334                          8.0
# 2159               67.517883                          8.0
# 2160               67.335590                          8.0
# 2161               67.117914                          8.0
# 2162               66.833321                          8.0
# 2163               66.617952                          8.0
# 2164               66.333359                          8.0
# 2165               66.479502                          8.0
# 2166               65.771864                          8.0
#
#       Land-En Zeezicht_storage_(ml)  Land-En Zeezicht_current_%  \
# 2147                        473.149                 104.9110865
# 2148                        473.149                 104.9110865
# 2149                        473.149                 104.9110865
# 2150                        473.149                 104.9110865
# 2151                        473.149                 104.9110865
# 2152                        473.149                 104.9110865
# 2153                        473.149                 104.9110865
# 2154                        473.149                 104.9110865
# 2155                        473.149                 104.9110865
# 2156                        473.149                 104.9110865
# 2157                        473.149                 104.9110865
# 2158                        473.149                 104.9110865
# 2159                        473.149                 104.9110865
# 2160                        473.149                 104.9110865
# 2161                        473.149                 104.9110865
# 2162                        473.149                 104.9110865
# 2163                        473.149                 104.9110865
# 2164                        473.149                 104.9110865
# 2165                        473.149                 104.9110865
# 2166                        473.149                 104.9110865
#
#       Land-En Zeezicht_last year_%
# 2147                           NaN
# 2148                           NaN
# 2149                           NaN
# 2150                           NaN
# 2151                           NaN
# 2152                           NaN
# 2153                           NaN
# 2154                           NaN
# 2155                           NaN
# 2156                           NaN
# 2157                           NaN
# 2158                           NaN
# 2159                           NaN
# 2160                           NaN
# 2161                           NaN
# 2162                           NaN
# 2163                           NaN
# 2164                           NaN
# 2165                           NaN
# 2166                           NaN
#
# [20 rows x 57 columns]

# %% [markdown]
# Since the last few rows aren't at all useful, I'll get rid of them

# %%
data = data[:2167]

# %%
bad_date_idx = data.loc[data['date'] > '2017-12-12'].index
max_bad_idx = max(bad_date_idx)
min_bad_idx = min(bad_date_idx)

print('The dates seem fine here...')
data.iloc[min_bad_idx-20:min_bad_idx]['date'].tolist()  
print('...The problem seems to start here...')
data.iloc[min_bad_idx:max_bad_idx+1]['date'].tolist()
print('...The problem seems to end there. Let\'s see the next few rows...')
data.loc[max_bad_idx+1:max_bad_idx+10]['date'].tolist()
# Out:
# The dates seem fine here...
# [Timestamp('2017-04-29 00:00:00'),
#  Timestamp('2017-04-30 00:00:00'),
#  Timestamp('2017-01-05 00:00:00'),
#  Timestamp('2017-02-05 00:00:00'),
#  Timestamp('2017-03-05 00:00:00'),
#  Timestamp('2017-04-05 00:00:00'),
#  Timestamp('2017-05-05 00:00:00'),
#  Timestamp('2017-06-05 00:00:00'),
#  Timestamp('2017-07-05 00:00:00'),
#  Timestamp('2017-08-08 00:00:00'),
#  Timestamp('2017-09-05 00:00:00'),
#  Timestamp('2017-10-05 00:00:00'),
#  Timestamp('2017-11-05 00:00:00'),
#  Timestamp('2017-12-05 00:00:00'),
#  Timestamp('2017-05-13 00:00:00'),
#  Timestamp('2017-05-14 00:00:00'),
#  Timestamp('2017-05-15 00:00:00'),
#  Timestamp('2017-05-16 00:00:00'),
#  Timestamp('2017-05-17 00:00:00'),
#  Timestamp('2017-05-18 00:00:00')]
# ...The problem seems to start here...
# [Timestamp('2018-05-19 00:00:00'),
#  Timestamp('2019-05-20 00:00:00'),
#  Timestamp('2020-05-21 00:00:00'),
#  Timestamp('2021-05-22 00:00:00')]
# ...The problem seems to end there. Let's see the next few rows...
# [Timestamp('2017-05-23 00:00:00'),
#  Timestamp('2017-05-24 00:00:00'),
#  Timestamp('2017-05-25 00:00:00'),
#  Timestamp('2017-05-26 00:00:00'),
#  Timestamp('2017-05-27 00:00:00'),
#  Timestamp('2017-05-28 00:00:00'),
#  Timestamp('2017-05-29 00:00:00'),
#  Timestamp('2017-05-30 00:00:00'),
#  Timestamp('2017-05-31 00:00:00'),
#  Timestamp('2017-06-01 00:00:00')]

# %%
(datetime.datetime(year = 2017, month = 12, day = 6) - data['date'].min()).days + 1
data.shape[0]
# Out:
# 2167
# 2167

# %%
for idx, d in data['date'].iteritems():
    if idx > 0:
        data.iloc[idx, 0] = data.iloc[idx - 1, 0] + datetime.timedelta(days = 1)

# %%
data['date'].min()
data['date'].max()
# Out:
# Timestamp('2012-01-01 00:00:00')
# Timestamp('2017-12-06 00:00:00')

# %% [markdown]
# # It's getting hot in here: melting our DataFrame

# %% [markdown]
# The data is 'wide' formatted (also known as 'pivoted'), with columns names repeated horizontally for dam. This isn't very easy for computers to read, so we'll need to do some wrangling to transform this into 'long' format. When we're done, there will be no duplicate column names but there will be an additional column to identify each dam.

# %%
dam_names = set(header_0)
dam_names = [d.title() for d in dam_names if not d.startswith('Total Stored')]

cols = data.columns.tolist()[1:]
dates = data['date']

dam_levels = pd.DataFrame()
for dam in dam_names:
    next_dam = pd.DataFrame({'date': dates,
                            'dam_name': dam})
    for col in cols:
        if re.search(dam, col):
            measure = re.sub(dam+'_', '', col)
            next_dam[measure] = data[col].replace(' ', '', regex = True).replace('#VALUE!', np.nan, regex = True)
            next_dam[measure] = next_dam[measure].astype(float)    
    dam_levels = pd.concat([dam_levels, next_dam], axis = 0)

dam_names = [dam.lower() for dam in dam_names]

# %%
dam_levels = dam_levels.rename(columns = {'height_(m)': 'height_m', 
                            'storage_(ml)': 'storage_ml',
                            'last year (%)': 'lastyear_%'})

# %%
dam_levels.head()
# Out:
#     dam_name       date  height_m  storage_ml  current_%  last year_%
# 0  Lewis Gay 2012-01-01      13.9       128.3       76.4          NaN
# 1  Lewis Gay 2012-01-02      13.9       128.3       76.4          NaN
# 2  Lewis Gay 2012-01-03      13.9       128.3       76.4          NaN
# 3  Lewis Gay 2012-01-04      13.9       128.3       76.4          NaN
# 4  Lewis Gay 2012-01-05      13.9       128.3       76.4          NaN

# %% [markdown]
# # Writing to disk

# %%
dam_levels.to_csv('/Users/jonathan/Google Drive/Data Science/Projects/Dam Levels/data/Dam-levels-clean-20120101-20171206.csv',
                 index = False)
